# %%
! pip install selenium

# %% [markdown]
# Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
# jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.naukri.com/data-analyst-jobs-in-bangalore-bengaluru?k=data%20analyst&l=bangalore%2Fbengaluru"
driver.get(url)   

#Scraping Data
job_title=[]
company_name=[]
job_location=[]
experience_required=[]

titles_tags=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
titles_tags[0:10]

for i in titles_tags:
    title=i.text
    job_title.append(title)
job_title[0:10]

company_tags=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
company_tags[0:10]

for i in company_tags:
    company=i.text
    company_name.append(company)
company_name[0:10] 

experience_tags=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']/span[1]")
experience_tags[0:10]

for i in experience_tags:
    experience=i.text
    experience_required.append(experience)
experience_required[0:10]

location_tags=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']")
location_tags[0:10]

for i in location_tags:
    location=i.text
    job_location.append(location)
job_location[0:10]

#Store data by using dataframe
df = pd.DataFrame()
df['Job_title']=job_title
df['Company_name']=company_name
df['Experience_required']=experience_required
df['Job_location']=job_location
df.head(10)

# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/ 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

url="https://www.naukri.com/data-scientist-jobs-in-bangalore-bengaluru?k=data%20scientist&l=bangalore%2Fbengaluru"
driver.get(url)   

#Scraping Data
job_title=[]
company_name=[]
job_location=[]

titles_tags=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
titles_tags[0:10]

for i in titles_tags:
    title=i.text
    job_title.append(title)
job_title[0:10]

company_tags=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
company_tags[0:10]

for i in company_tags:
    company=i.text
    company_name.append(company)
company_name[0:10]    

location_tags=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']")
location_tags[0:10]

for i in location_tags:
    location=i.text
    job_location.append(location)
job_location[0:10]

#Store data by using dataframe
df = pd.DataFrame()
df['Job_title']=job_title
df['Company_name']=company_name
df['Job_location']=job_location
df.head(10)

# %% [markdown]
# Q3: In this question you have to scrape data using the filters available on the webpage as shown below:
# You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results.
# You have to scrape the job-title, job-location, company name, experience required.
# The location filter to be used is “Delhi/NCR” The salary filter to be used is “3-6” lakhs
# The task will be done as shown in the below steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, and Companies” field.
# 3. Then click the search button.
# 4. Then apply the location filter and salary filter by checking the respective boxes
# 5. Then scrape the data for the first 10 jobs results you get.
# 6. Finally create a dataframe of the scraped data.

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.naukri.com/data-scientist-jobs?k=data%20scientist&cityTypeGid=9508&ctcFilter=3to6"
driver.get(url)   

#Scraping Data
job_title=[]
company_name=[]
job_location=[]
experience_required=[]

titles_tags=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
titles_tags[0:10]

for i in titles_tags:
    title=i.text
    job_title.append(title)
job_title[0:10]

company_tags=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
company_tags[0:10]

for i in company_tags:
    company=i.text
    company_name.append(company)
company_name[0:10] 

experience_tags=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']/span[1]")
experience_tags[0:10]

for i in experience_tags:
    experience=i.text
    experience_required.append(experience)
experience_required[0:10]

location_tags=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']")
location_tags[0:10]

for i in location_tags:
    location=i.text
    job_location.append(location)
job_location[0:10]

#Store data by using dataframe
df = pd.DataFrame()
df['Job_title']=job_title
df['Company_name']=company_name
df['Experience_required']=experience_required
df['Job_location']=job_location
df.head(10)

# %% [markdown]
# Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. Product Description
# 3. Price
# The attributes which you have to scrape is ticked marked in the below image.
# To scrape the data you have to go through following steps:
# 1. Go to Flipkart webpage by url : https://www.flipkart.com/
# 2. Enter “sunglasses” in the search field where “search for products, brands and more” is written and
# click the search icon
# 3. After that you will reach to the page having a lot of sunglasses. From this page you can scrap the
# required data as usual.
# 4. After scraping data from the first page, go to the “Next” Button at the bottom of the page , then
# click on it.
# 5. Now scrape data from this page as usual
# 6. Repeat this until you get data for 100 sunglasses.

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
driver.get(url)   

#Scraping Data
brand_name=[]
product_description=[]
price=[]

brand_tags=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
brand_tags[0:40]

for i in brand_tags:
    brand=i.text
    brand_name.append(brand)
brand_name[0:40]

product_tags=driver.find_elements_by_xpath("//a[@class='IRpwTa']")
product_tags[0:40]

for i in product_tags:
    product=i.text
    product_description.append(product)
product_description[0:40]    

price_tags=driver.find_elements_by_xpath("//div[@class='_30jeq3']")
price_tags[0:40]

for i in price_tags:
    rate=i.text
    price.append(rate)
price[0:40]

#Store data by using dataframe
df = pd.DataFrame()
df['Brand']=brand_name
df['Product_description']=product_description
df['Price']=price
df.head(40)

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2"
driver.get(url)   

#Scraping Data
brand_name=[]
product_description=[]
price=[]

brand_tags=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
brand_tags[0:40]

for i in brand_tags:
    brand=i.text
    brand_name.append(brand)
brand_name[0:40]

product_tags=driver.find_elements_by_xpath("//a[@class='IRpwTa']")
product_tags[0:40]

for i in product_tags:
    product=i.text
    product_description.append(product)
product_description[0:40]    

price_tags=driver.find_elements_by_xpath("//div[@class='_30jeq3']")
price_tags[0:40]

for i in price_tags:
    rate=i.text
    price.append(rate)
price[0:40]

#Store data by using dataframe
df = pd.DataFrame()
df['Brand']=brand_name[0:40] 
df['Product_description']=product_description[0:40] 
df['Price']=price[0:40] 
df.head(40)

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

url="https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3"
driver.get(url)   

#Scraping Data
brand_name=[]
product_description=[]
price=[]

brand_tags=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
brand_tags[0:20]

for i in brand_tags:
    brand=i.text
    brand_name.append(brand)
brand_name[0:20]

product_tags=driver.find_elements_by_xpath("//a[@class='IRpwTa']")
product_tags[0:20]

for i in product_tags:
    product=i.text
    product_description.append(product)
product_description[0:20]    

price_tags=driver.find_elements_by_xpath("//div[@class='_30jeq3']")
price_tags[0:20]

for i in price_tags:
    rate=i.text
    price.append(rate)
price[0:20]

#Store data by using dataframe
df = pd.DataFrame()
df['Brand']=brand_name[0:20]
df['Product_description']=product_description[0:20]
df['Price']=price[0:20]
df.head(20)

# %% [markdown]
# Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link:
# https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKC
# TSVZAXUHGREPBFGI&marketplace.
# When you will open the above link you will reach to the below shown webpage.
# As shown in the above page you have to scrape the tick marked attributes.These are:
# 1. Rating
# 2. Review_summary
# 3. Full review
# 4. You have to scrape this data for first 100 reviews

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART"
driver.get(url)   

#Scraping Data
rating=[]
review_summary=[]
full_review=[]

rating_tags=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rating_tags[0:10]

for i in rating_tags:
    score=i.text
    rating.append(score)
rating[0:10]

review_summary_tags=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_summary_tags[0:10]

for i in review_summary_tags:
    summary=i.text
    review_summary.append(summary)
review_summary[0:10]    

full_review_tags=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
full_review_tags[0:10]

for i in full_review_tags:
    review=i.text
    full_review.append(review)
full_review[0:10]

#Store data by using dataframe
df = pd.DataFrame()
df['Rating']=rating
df['Review_summary']=review_summary
df['Full_review']=full_review
df.head(10)

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=2"
driver.get(url)   

#Scraping Data
rating=[]
review_summary=[]
full_review=[]

rating_tags=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rating_tags[0:10]

for i in rating_tags:
    score=i.text
    rating.append(score)
rating[0:10]

review_summary_tags=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_summary_tags[0:10]

for i in review_summary_tags:
    summary=i.text
    review_summary.append(summary)
review_summary[0:10]    

full_review_tags=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
full_review_tags[0:10]

for i in full_review_tags:
    review=i.text
    full_review.append(review)
full_review[0:10]

#Store data by using dataframe
df = pd.DataFrame()
df['Rating']=rating
df['Review_summary']=review_summary
df['Full_review']=full_review
df.head(10)

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=3"
driver.get(url)   

#Scraping Data
rating=[]
review_summary=[]
full_review=[]

rating_tags=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rating_tags[0:10]

for i in rating_tags:
    score=i.text
    rating.append(score)
rating[0:10]

review_summary_tags=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_summary_tags[0:10]

for i in review_summary_tags:
    summary=i.text
    review_summary.append(summary)
review_summary[0:10]    

full_review_tags=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
full_review_tags[0:10]

for i in full_review_tags:
    review=i.text
    full_review.append(review)
full_review[0:10]

#Store data by using dataframe
df = pd.DataFrame()
df['Rating']=rating
df['Review_summary']=review_summary
df['Full_review']=full_review
df.head(10)

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=4"
driver.get(url)   

#Scraping Data
rating=[]
review_summary=[]
full_review=[]

rating_tags=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rating_tags[0:10]

for i in rating_tags:
    score=i.text
    rating.append(score)
rating[0:10]

review_summary_tags=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_summary_tags[0:10]

for i in review_summary_tags:
    summary=i.text
    review_summary.append(summary)
review_summary[0:10]    

full_review_tags=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
full_review_tags[0:10]

for i in full_review_tags:
    review=i.text
    full_review.append(review)
full_review[0:10]

#Store data by using dataframe
df = pd.DataFrame()
df['Rating']=rating
df['Review_summary']=review_summary
df['Full_review']=full_review
df.head(10)

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=5"
driver.get(url)   

#Scraping Data
rating=[]
review_summary=[]
full_review=[]

rating_tags=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rating_tags[0:10]

for i in rating_tags:
    score=i.text
    rating.append(score)
rating[0:10]

review_summary_tags=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_summary_tags[0:10]

for i in review_summary_tags:
    summary=i.text
    review_summary.append(summary)
review_summary[0:10]    

full_review_tags=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
full_review_tags[0:10]

for i in full_review_tags:
    review=i.text
    full_review.append(review)
full_review[0:10]

#Store data by using dataframe
df = pd.DataFrame()
df['Rating']=rating
df['Review_summary']=review_summary
df['Full_review']=full_review
df.head(10)

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=6"
driver.get(url)   

#Scraping Data
rating=[]
review_summary=[]
full_review=[]

rating_tags=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rating_tags[0:10]

for i in rating_tags:
    score=i.text
    rating.append(score)
rating[0:10]

review_summary_tags=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_summary_tags[0:10]

for i in review_summary_tags:
    summary=i.text
    review_summary.append(summary)
review_summary[0:10]    

full_review_tags=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
full_review_tags[0:10]

for i in full_review_tags:
    review=i.text
    full_review.append(review)
full_review[0:10]

#Store data by using dataframe
df = pd.DataFrame()
df['Rating']=rating
df['Review_summary']=review_summary
df['Full_review']=full_review
df.head(10)

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=7"
driver.get(url)   

#Scraping Data
rating=[]
review_summary=[]
full_review=[]

rating_tags=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rating_tags[0:10]

for i in rating_tags:
    score=i.text
    rating.append(score)
rating[0:10]

review_summary_tags=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_summary_tags[0:10]

for i in review_summary_tags:
    summary=i.text
    review_summary.append(summary)
review_summary[0:10]    

full_review_tags=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
full_review_tags[0:10]

for i in full_review_tags:
    review=i.text
    full_review.append(review)
full_review[0:10]

#Store data by using dataframe
df = pd.DataFrame()
df['Rating']=rating
df['Review_summary']=review_summary
df['Full_review']=full_review
df.head(10)

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=8"
driver.get(url)   

#Scraping Data
rating=[]
review_summary=[]
full_review=[]

rating_tags=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rating_tags[0:10]

for i in rating_tags:
    score=i.text
    rating.append(score)
rating[0:10]

review_summary_tags=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_summary_tags[0:10]

for i in review_summary_tags:
    summary=i.text
    review_summary.append(summary)
review_summary[0:10]    

full_review_tags=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
full_review_tags[0:10]

for i in full_review_tags:
    review=i.text
    full_review.append(review)
full_review[0:10]

#Store data by using dataframe
df = pd.DataFrame()
df['Rating']=rating
df['Review_summary']=review_summary
df['Full_review']=full_review
df.head(10)

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=9"
driver.get(url)   

#Scraping Data
rating=[]
review_summary=[]
full_review=[]

rating_tags=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rating_tags[0:10]

for i in rating_tags:
    score=i.text
    rating.append(score)
rating[0:10]

review_summary_tags=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_summary_tags[0:10]

for i in review_summary_tags:
    summary=i.text
    review_summary.append(summary)
review_summary[0:10]    

full_review_tags=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
full_review_tags[0:10]

for i in full_review_tags:
    review=i.text
    full_review.append(review)
full_review[0:10]

#Store data by using dataframe
df = pd.DataFrame()
df['Rating']=rating
df['Review_summary']=review_summary
df['Full_review']=full_review
df.head(10)

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=10"
driver.get(url)   

#Scraping Data
rating=[]
review_summary=[]
full_review=[]

rating_tags=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rating_tags[0:10]

for i in rating_tags:
    score=i.text
    rating.append(score)
rating[0:10]

review_summary_tags=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_summary_tags[0:10]

for i in review_summary_tags:
    summary=i.text
    review_summary.append(summary)
review_summary[0:10]    

full_review_tags=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
full_review_tags[0:10]

for i in full_review_tags:
    review=i.text
    full_review.append(review)
full_review[0:10]

#Store data by using dataframe
df = pd.DataFrame()
df['Rating']=rating
df['Review_summary']=review_summary
df['Full_review']=full_review
df.head(10)

# %% [markdown]
# Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the
# search field.
# You have to scrape 4 attributes of each sneaker:
# 1. Brand
# 2. Product Description
# 3. Price
#
# As shown in the below image, you have to scrape the tick marked attributes.

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.flipkart.com/search?q=sneakers&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
driver.get(url)   

#Scraping Data
brand_name=[]
product_description=[]
price=[]
discount_percentage=[]

brand_tags=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
brand_tags

for i in brand_tags:
    brand=i.text
    brand_name.append(brand)
brand_name

product_tags=driver.find_elements_by_xpath("//div[@class='_2B099V']/a[1]")
product_tags

for i in product_tags:
    product=i.text
    product_description.append(product)
product_description  

price_tags=driver.find_elements_by_xpath("//div[@class='_30jeq3']")
price_tags

for i in price_tags:
    rate=i.text
    price.append(rate)
price

discount_tags=driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']/span[1]")
discount_tags

for i in discount_tags:
    disct=i.text
    discount_percentage.append(disct)
discount_percentage

#Store data by using dataframe
df = pd.DataFrame()
df['Brand']=brand_name
df['Product_description']=product_description
df['Price']=price
df['Discount_percentage']=discount_percentage
df

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.flipkart.com/search?q=sneakers&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2"
driver.get(url)   

#Scraping Data
brand_name=[]
product_description=[]
price=[]
discount_percentage=[]

brand_tags=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
brand_tags

for i in brand_tags:
    brand=i.text
    brand_name.append(brand)
brand_name

product_tags=driver.find_elements_by_xpath("//div[@class='_2B099V']/a[1]")
product_tags

for i in product_tags:
    product=i.text
    product_description.append(product)
product_description  

price_tags=driver.find_elements_by_xpath("//div[@class='_30jeq3']")
price_tags

for i in price_tags:
    rate=i.text
    price.append(rate)
price

discount_tags=driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']/span[1]")
discount_tags

for i in discount_tags:
    disct=i.text
    discount_percentage.append(disct)
discount_percentage

#Store data by using dataframe
df = pd.DataFrame()
df['Brand']=brand_name
df['Product_description']=product_description
df['Price']=price
df['Discount_percentage']=discount_percentage
df

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.flipkart.com/search?q=sneakers&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3"
driver.get(url)   

#Scraping Data
brand_name=[]
product_description=[]
price=[]
discount_percentage=[]

brand_tags=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
brand_tags

for i in brand_tags:
    brand=i.text
    brand_name.append(brand)
brand_name

product_tags=driver.find_elements_by_xpath("//div[@class='_2B099V']/a[1]")
product_tags

for i in product_tags:
    product=i.text
    product_description.append(product)
product_description  

price_tags=driver.find_elements_by_xpath("//div[@class='_30jeq3']")
price_tags

for i in price_tags:
    rate=i.text
    price.append(rate)
price

discount_tags=driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']/span[1]")
discount_tags

for i in discount_tags:
    disct=i.text
    discount_percentage.append(disct)
discount_percentage

#Store data by using dataframe
df = pd.DataFrame()
df['Brand']=brand_name
df['Product_description']=product_description
df['Price']=price
df['Discount_percentage']=discount_percentage
df.head(20)

# %% [markdown]
# Q7: Go to the link - https://www.myntra.com/shoes
# Set Price filter to “Rs. 6649 to Rs. 13099” , Color filter to “Black”, as shown in the below image.
# And then scrape First 100 shoes data you get. The data should include “Brand” of the shoes , Short Shoe
# description, price of the shoe as shown in the below image.

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.myntra.com/shoes?f=Color%3ABlack_36454f&rf=Price%3A7149.0_14099.0_7149.0%20TO%2014099.0%2C7164.0_14109.0_7164.0%20TO%2014109.0"
driver.get(url)   

#Scraping Data
brand_name=[]
shoe_description=[]
price=[]

brand_tags=driver.find_elements_by_xpath("//h3[@class='product-brand']")
brand_tags[0:50]

for i in brand_tags:
    brand=i.text
    brand_name.append(brand)
brand_name[0:50]

description_tags=driver.find_elements_by_xpath("//h4[@class='product-product']")
description_tags[0:50]

for i in description_tags:
    shoe=i.text
    product_description.append(shoe)
shoe_description[0:50]    

price_tags=driver.find_elements_by_xpath("//div[@class='product-price']/span[1]")
price_tags[0:50]

for i in price_tags:
    rate=i.text
    price.append(rate)
price[0:50]

#Store data by using dataframe
df = pd.DataFrame()
df['Brand']=brand_name
df['Shoe_description']=shoe_description
df['Price']=price
df.head(50)

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.myntra.com/shoes?f=Color%3ABlack_36454f&p=2&rf=Price%3A7149.0_14099.0_7149.0%20TO%2014099.0%2C7164.0_14109.0_7164.0%20TO%2014109.0"
driver.get(url)   

#Scraping Data
brand_name=[]
shoe_description=[]
price=[]

brand_tags=driver.find_elements_by_xpath("//h3[@class='product-brand']")
brand_tags[0:50]

for i in brand_tags:
    brand=i.text
    brand_name.append(brand)
brand_name[0:50]

description_tags=driver.find_elements_by_xpath("//h4[@class='product-product']")
description_tags[0:50]

for i in description_tags:
    shoe=i.text
    product_description.append(shoe)
shoe_description[0:50]    

price_tags=driver.find_elements_by_xpath("//div[@class='product-price']/span[1]")
price_tags[0:50]

for i in price_tags:
    rate=i.text
    price.append(rate)
price[0:50]

#Store data by using dataframe
df = pd.DataFrame()
df['Brand']=brand_name
df['Shoe_description']=shoe_description
df['Price']=price
df.head(50)

# %% [markdown]
# Q8: Go to webpage https://www.amazon.in/
# Enter “Laptop” in the search field and then click the search icon.
# Then set CPU Type filter to “Intel Core i7” and “Intel Core i9” as shown in the below image:
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributes for each laptop:
# 1. Title
# 2. Ratings
# 3. Price
#
# As shown in the below image as the tick marked attributes.

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.amazon.in/s?k=laptop&rh=n%3A1375424031%2Cp_n_feature_thirteen_browse-bin%3A12598163031&dc&qid=1636916479&rnid=12598141031&ref=sr_nr_p_n_feature_thirteen_browse-bin_12"
driver.get(url)   

#Scraping Data
title=[]
rating=[]
price=[]

title_tags=driver.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']")
title_tags[0:10]

for i in title_tags:
    j=i.text
    title.append(j)
title[0:10]

rating_tags=driver.find_elements_by_xpath("//span[@class='a-icon-alt']")
rating_tags[0:10]

for i in rating_tags:
    j=i.text
    rating.append(j)
rating[0:10]    

price_tags=driver.find_elements_by_xpath("//span[@class='a-price-whole']")
price_tags[0:10]

for i in price_tags:
    rate=i.text
    price.append(rate)
price[0:10]

#Store data by using dataframe
df = pd.DataFrame()
df['Title']=title
df['Rating']=rating
df['Price']=price
df.head(10)

# %% [markdown]
# Q9: Write a python program to scrape data for first 10 job results for Data Scientist Designation in Noida
# location. You have to scrape company name, No. of days ago when job was posted, Rating of the company.
# This task will be done in following steps:
# 1. First get the webpage https://www.ambitionbox.com/
# 2. Click on the Job option as shown in the image
# 3. After reaching to the next webpage, In place of “Search by Designations, Companies, Skills” enter
# “Data Scientist” and click on search button.
# 4. You will reach to the following web page click on location and in place of “Search location” enter
# “Noida” and select location “Noida”.
# 5. Then scrape the data for the first 10 jobs results you get on the above shown page.
# 6. Finally create a dataframe of the scraped data.

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.ambitionbox.com/jobs/search?designation=data-scientist&location=Noida"
driver.get(url)   

#Scraping Data
company_name=[]
no_of_days_posted=[]
company_rating=[]

company_tags=driver.find_elements_by_xpath("//p[@class='company body-medium']")
company_tags[0:10]

for i in company_tags:
    company=i.text
    company_name.append(company)
company_name[0:10] 

no_0f_days_tags=driver.find_elements_by_xpath("//div[@class='other-info']/span[1]")
no_0f_days_tags[0:10]

for i in no_0f_days_tags:
    days=i.text
    no_of_days_posted.append(days)
no_of_days_posted[0:10]

rating_tags=driver.find_elements_by_xpath("//div[@class='rating-wrapper']/a/span")
rating_tags[1:11]

for i in rating_tags:
    rating=i.text
    company_rating.append(rating)
company_rating[1:11] 

#Store data by using dataframe
df = pd.DataFrame()
df['Company_name']=company_name
df['No_of_days_ ago_when_job_was_posted']=no_of_days_posted
df['Rating_of_the_company']=company_rating[1:11]
df

# %% [markdown]
# Q10: Write a python program to scrape the salary data for Data Scientist designation.
# You have to scrape Company name, Number of salaries, Average salary, Min salary, Max Salary.
# The above task will be, done as shown in the below steps:
# 1. First get the webpage https://www.ambitionbox.com/
# 2. Click on the salaries option as shown in the image.
# 3. After reaching to the following webpage, In place of “Search Job Profile” enters “Data Scientist” and
# then click on “Data Scientist”.
# You have to scrape the data ticked in the above image.
# 4. Scrape the data for the first 10 companies. Scrape the company name, total salary record, average
# salary, minimum salary, maximum salary, experience required.
# 5. Store the data in a dataframe.

# %%
#importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome(r"C:/Users/HP/Downloads/chromedriver_win32/chromedriver.exe")

url="https://www.ambitionbox.com/profile/data-scientist-salary"
driver.get(url)   

#Scraping Data
company_name=[]
total_salary=[]
average_salary=[]
minimum_salary=[]
maximum_salary=[]
experience_required=[]

company_tags=driver.find_elements_by_xpath("//div[@class='name']/a")
company_tags[0:10]

for i in company_tags:
    company=i.text
    company_name.append(company)
company_name[0:10]

total_tags=driver.find_elements_by_xpath("//div[@class='name']/span")
total_tags[0:10]

for i in total_tags:
    j=i.text
    total_salary.append(j)
total_salary[0:10]

average_tags=driver.find_elements_by_xpath("//p[@class='averageCtc']")
average_tags[9:19]

for i in average_tags:
    j=i.text
    average_salary.append(j)
average_salary[9:19]

minimum_tags=driver.find_elements_by_xpath("//div[@class='salary-values']/div[1]")
minimum_tags[9:19]

for i in minimum_tags:
    j=i.text
    minimum_salary.append(j)
minimum_salary[9:19]

maximum_tags=driver.find_elements_by_xpath("//div[@class='salary-values']/div[2]")
maximum_tags[9:19]

for i in maximum_tags:
    j=i.text
    maximum_salary.append(j)
maximum_salary[9:19]

experience_tags=driver.find_elements_by_xpath("//div[@class='salaries one-line sbold-list-header']")
experience_tags[0:10]

for i in experience_tags:
    experience=i.text
    experience_required.append(experience)
experience_required[0:10]

#Store data by using dataframe
df = pd.DataFrame()
df['Company_name']=company_name
df['Total_salary']=total_salary
df['Average_salary']=average_salary[9:19]
df['Minimum_salary']=minimum_salary[9:19]
df['Maximum_salary']=maximum_salary[9:19]
df['Experience_required']=experience_required
df
